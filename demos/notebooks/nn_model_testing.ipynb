# %%
import os
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ["KERAS_BACKEND"] = "torch"

import bokeh.plotting as bpl
import cv2
import holoviews as hv
import logging
import matplotlib.pyplot as plt
from multiprocessing import Process, Queue, set_start_method
import numpy as np
from scipy.sparse import csr_matrix
from sys import platform
# import tensorflow as tf
import torch 
from time import time, sleep

try:
    if __IPYTHON__:
        get_ipython().run_line_magic('load_ext', 'autoreload')
        get_ipython().run_line_magic('autoreload', '2')
except NameError:
    pass

logging.basicConfig(format=
                          "%(relativeCreated)12d [%(filename)s:%(funcName)10s():%(lineno)s] [%(process)d] %(message)s",
                    # filename="/tmp/caiman.log",
                    level=logging.WARNING)

import caiman as cm
from caiman.source_extraction import cnmf
from caiman.source_extraction.cnmf.online_cnmf import demix1p
from caiman.utils.nn_models import (fit_NL_model, create_LN_model, quantile_loss, rate_scheduler)
from caiman.utils.utils import download_demo

bpl.output_notebook()
hv.notebook_extension('bokeh')
# Out:
# 2024-07-30 15:56:19.982746: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-30 15:56:20.335099: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /mnt/home/mpaez/miniconda3/envs/caiman_pytorch/lib/python3.11/site-packages/torch/cuda/__init__.py:619: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cd74b462-9079-4529-a196-379809e8f3b3">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="f885fd8a-2721-40c1-8050-96275cae31c0" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6ef1f0ae-92ac-4363-9099-c2c1d36b5052":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"89105adb26d2427384ddd1bf27cfa2cb","client_comm_id":"d54d99d4dd9d4660bc45073d13505c5a"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"6ef1f0ae-92ac-4363-9099-c2c1d36b5052","roots":{"p1002":"f885fd8a-2721-40c1-8050-96275cae31c0"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
def get_iterator(device=0, fr=None):
    """
    device: device number (int) or filename (string) for reading from camera or file respectively
    fr: frame rate
    """
    if isinstance(device, int):  # capture from camera
        def capture_iter(device=device, fr=fr):
            cap = cv2.VideoCapture(device)
            if fr is not None:  # set frame rate
                cap.set(cv2.CAP_PROP_FPS, fr)
            while True:
                yield cv2.cvtColor(cap.read()[1], cv2.COLOR_BGR2GRAY)
        iterator = capture_iter(device, fr)
    else:  # read frame by frame from file
        iterator = cm.base.movies.load_iter(device, var_name_hdf5='Y')
    return iterator

# %%
init_batch = 100  # number of frames to use for initialization
T = 6000          # total number of frames 
fr = 10           # frame rate (Hz)

iterator = get_iterator(download_demo('blood_vessel_10Hz.mat'))

m = cm.movie(np.array([next(iterator) for t in range(init_batch)], dtype='float32'))

# %%
fname_init = m.save('init.mmap', order='C')

# %%
reuse_model = False                                       # set to True to reuse an existing ring model
path_to_model = None                                      # specify a pre-trained model here if needed 
gSig = (7, 7)                                             # expected half size of neurons
gnb = 2                                                   # number of background components for OnACID

params_dict = {'fnames': fname_init,                      # filename(s) to be processed
               'var_name_hdf5': 'Y',                      # name of variable inside mat file where the data is stored
               'fr': fr,                                  # frame rate (Hz)
               'decay_time': 0.5,                         # approximate length of transient event in seconds
               'gSig': gSig,                              # gaussian width of a 2D gaussian kernel, which approximates a neuron
               'p': 1,                                    # order of AR indicator dynamics
               'ring_CNN': True,                          # SET TO TRUE TO USE RING CNN 
               'min_SNR': 2.65,                           # minimum SNR for accepting new components
               'SNR_lowest': 0.75,                        # reject components with SNR below this value
               'use_cnn': False,                          # do not use CNN based test for components
               'use_ecc': True,                           # test eccentricity
               'max_ecc': 2.625,                          # reject components with eccentricity above this value
               'rval_thr': 0.70,                          # correlation threshold for new component inclusion
               'rval_lowest': 0.25,                       # reject components with corr below that value
               'ds_factor': 1,                            # spatial downsampling factor (increases speed but may lose some fine structure)
               'nb': gnb,                                 # number of background components (rank)
               'motion_correct': True,                    # Flag for motion correction
               'init_batch': init_batch,                  # number of frames for initialization (presumably from the first file)
               'init_method': 'bare',                     # initialization method
               'normalize': False,                        # Whether to normalize each frame prior to online processing
               'expected_comps': 700,                     # maximum number of expected components used for memory pre-allocation (exaggerate here)
               'sniper_mode': False,                      # flag using a CNN to detect new neurons (o/w space correlation is used)
               'dist_shape_update' : True,                # flag for updating shapes in a distributed way
               'min_num_trial': 5,                        # number of candidate components per frame
               'epochs': 1,                               # number of total passes over the data
               'stop_detection': False,                   # Run a last epoch without detecting new neurons  
               'K': 50,                                   # initial number of components
               'lr': 6e-4,                                # (initial) learning rate
               'lr_scheduler': [0.9, 6000, 10000],        # learning rate scheduler
               'pct': 0.01,                               # quantile of the quantile loss function
               'path_to_model': path_to_model,            # where the ring CNN model is saved/loaded
               'reuse_model': reuse_model,                # flag for re-using a ring CNN model
              }
opts = cnmf.params.CNMFParams(params_dict=params_dict)
# Out:
#        34727 [params.py:change_params():1150] [1091161] In setting CNMFParams, non-pathed parameters were used; this is deprecated. In some future version of Caiman, allow_legacy will default to False (and eventually will be removed)

# %%
cnm3 = cnmf.online_cnmf.OnACID(params=opts)

if cnm3.params.get('ring_CNN', 'loss_fn') == 'pct':
    loss_fn = quantile_loss(cnm3.params.get('ring_CNN', 'pct'))
else:
    loss_fn = cnm3.params.get('ring_CNN', 'loss_fn')
if cnm3.params.get('ring_CNN', 'lr_scheduler') is None:
    sch = None
else:
    sch = rate_scheduler(*cnm3.params.get('ring_CNN', 'lr_scheduler'))
model_LN = create_LN_model(m, shape=m.shape[1:] + (1,),
                           n_channels=cnm3.params.get('ring_CNN', 'n_channels'),
                           lr=cnm3.params.get('ring_CNN', 'lr'),
                           gSig=cnm3.params.get('init', 'gSig')[0],
                           loss=loss_fn, width=cnm3.params.get('ring_CNN', 'width'),
                           use_add=cnm3.params.get('ring_CNN', 'use_add'),
                           use_bias=cnm3.params.get('ring_CNN', 'use_bias'))

if cnm3.params.get('ring_CNN', 'reuse_model'):
    model_LN.load_weights(cnm3.params.get('ring_CNN', 'path_to_model'))
else:
    model_LN, history, path_to_model = fit_NL_model(
        model_LN, m, epochs=cnm3.params.get('ring_CNN', 'max_epochs'),
        patience=cnm3.params.get('ring_CNN', 'patience'), schedule=sch)
    cnm3.params.set('ring_CNN', {'path_to_model': path_to_model})
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0006000000284984708.
# Epoch 1/100
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 2s 3s/step - loss: 12.4644
# /mnt/home/mpaez/miniconda3/envs/caiman_pytorch/lib/python3.11/site-packages/caiman/utils/nn_models.py:206: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.R = torch.tensor(self.R).float()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 8s/step - loss: 13.1399 - val_loss: 13.8464 - learning_rate: 6.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0005632442627684073.
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 13.2878 - val_loss: 10.9440 - learning_rate: 5.6324e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0005287401542852935.
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 10.4194 - val_loss: 8.1271 - learning_rate: 5.2874e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0004963497577430219.
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 7.6249 - val_loss: 5.3963 - learning_rate: 4.9635e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.00046594357188006166.
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 4.9184 - val_loss: 3.0465 - learning_rate: 4.6594e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.00043740004582878625.
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 3.2687 - val_loss: 3.7546 - learning_rate: 4.3740e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.00041060508733853037.
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 3.3337 - val_loss: 2.3079 - learning_rate: 4.1061e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.00038545157099864814.
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 2.3194 - val_loss: 2.4049 - learning_rate: 3.8545e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0003618389557453349.
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 2.4003 - val_loss: 2.3215 - learning_rate: 3.6184e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.00033967284772656777.
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 2.2552 - val_loss: 1.9124 - learning_rate: 3.3967e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0003188646178089277.
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 1.8079 - val_loss: 2.0195 - learning_rate: 3.1886e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.00029933110104724605.
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 1.7688 - val_loss: 1.5239 - learning_rate: 2.9933e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0002809941868704855.
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 1.5214 - val_loss: 1.4773 - learning_rate: 2.8099e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0002637806005142103.
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 1.4487 - val_loss: 1.4514 - learning_rate: 2.6378e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.00024762149320646737.
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.3964 - val_loss: 1.3725 - learning_rate: 2.4762e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.00023245230556308006.
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.3567 - val_loss: 1.3604 - learning_rate: 2.3245e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.000218212371434.
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.3294 - val_loss: 1.3070 - learning_rate: 2.1821e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0002048447676381303.
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.2883 - val_loss: 1.2849 - learning_rate: 2.0484e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.00019229605441438354.
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.2579 - val_loss: 1.2460 - learning_rate: 1.9230e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0001805160705146225.
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.2224 - val_loss: 1.2200 - learning_rate: 1.8052e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.00016945772829660065.
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.1961 - val_loss: 1.1943 - learning_rate: 1.6946e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.00015907680881690293.
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.1686 - val_loss: 1.1714 - learning_rate: 1.5908e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.0001493318252262393.
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.1446 - val_loss: 1.1538 - learning_rate: 1.4933e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.00014018381786238559.
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 1.1242 - val_loss: 1.1364 - learning_rate: 1.4018e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.000131596217645477.
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.1068 - val_loss: 1.1230 - learning_rate: 1.3160e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.00012353468215236068.
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 1.0914 - val_loss: 1.1086 - learning_rate: 1.2353e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.00011596699999330154.
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 1.0759 - val_loss: 1.0968 - learning_rate: 1.1597e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00010886290639562848.
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 1.0645 - val_loss: 1.0864 - learning_rate: 1.0886e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.00010219400807114617.
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 1.0523 - val_loss: 1.0760 - learning_rate: 1.0219e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 9.593364661142873e-05.
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 1.0416 - val_loss: 1.0676 - learning_rate: 9.5934e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 9.005678920405472e-05.
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 1.0329 - val_loss: 1.0598 - learning_rate: 9.0057e-05
#
# Epoch 32: LearningRateScheduler setting learning rate to 8.453994666978343e-05.
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.0233 - val_loss: 1.0517 - learning_rate: 8.4540e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 7.936106417878977e-05.
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.0169 - val_loss: 1.0456 - learning_rate: 7.9361e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 7.449943928784063e-05.
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.0098 - val_loss: 1.0394 - learning_rate: 7.4499e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 6.993563314723579e-05.
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 1.0033 - val_loss: 1.0340 - learning_rate: 6.9936e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 6.565140219845473e-05.
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9975 - val_loss: 1.0290 - learning_rate: 6.5651e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 6.162962304156824e-05.
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9915 - val_loss: 1.0241 - learning_rate: 6.1630e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 5.7854217302649974e-05.
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9868 - val_loss: 1.0200 - learning_rate: 5.7854e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 5.431009016165864e-05.
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9819 - val_loss: 1.0157 - learning_rate: 5.4310e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 5.0983075710555477e-05.
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9782 - val_loss: 1.0122 - learning_rate: 5.0983e-05
#
# Epoch 41: LearningRateScheduler setting learning rate to 4.785987206606879e-05.
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9748 - val_loss: 1.0092 - learning_rate: 4.7860e-05
#
# Epoch 42: LearningRateScheduler setting learning rate to 4.492799355804677e-05.
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9710 - val_loss: 1.0055 - learning_rate: 4.4928e-05
#
# Epoch 43: LearningRateScheduler setting learning rate to 4.21757229178103e-05.
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9675 - val_loss: 1.0031 - learning_rate: 4.2176e-05
#
# Epoch 44: LearningRateScheduler setting learning rate to 3.959205322115279e-05.
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9644 - val_loss: 1.0002 - learning_rate: 3.9592e-05
#
# Epoch 45: LearningRateScheduler setting learning rate to 3.716666056739894e-05.
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9613 - val_loss: 0.9975 - learning_rate: 3.7167e-05
#
# Epoch 46: LearningRateScheduler setting learning rate to 3.4889846022404555e-05.
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9580 - val_loss: 0.9954 - learning_rate: 3.4890e-05
#
# Epoch 47: LearningRateScheduler setting learning rate to 3.2752508297615337e-05.
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9556 - val_loss: 0.9930 - learning_rate: 3.2753e-05
#
# Epoch 48: LearningRateScheduler setting learning rate to 3.074610276865495e-05.
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9539 - val_loss: 0.9913 - learning_rate: 3.0746e-05
#
# Epoch 49: LearningRateScheduler setting learning rate to 2.8862607324148504e-05.
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9519 - val_loss: 0.9893 - learning_rate: 2.8863e-05
#
# Epoch 50: LearningRateScheduler setting learning rate to 2.7094495044781296e-05.
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9495 - val_loss: 0.9874 - learning_rate: 2.7094e-05
#
# Epoch 51: LearningRateScheduler setting learning rate to 2.5434696637004567e-05.
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9485 - val_loss: 0.9860 - learning_rate: 2.5435e-05
#
# Epoch 52: LearningRateScheduler setting learning rate to 2.3876576527211926e-05.
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9467 - val_loss: 0.9842 - learning_rate: 2.3877e-05
#
# Epoch 53: LearningRateScheduler setting learning rate to 2.2413907248356923e-05.
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9446 - val_loss: 0.9827 - learning_rate: 2.2414e-05
#
# Epoch 54: LearningRateScheduler setting learning rate to 2.1040840411452966e-05.
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9440 - val_loss: 0.9814 - learning_rate: 2.1041e-05
#
# Epoch 55: LearningRateScheduler setting learning rate to 1.9751886214867385e-05.
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9414 - val_loss: 0.9801 - learning_rate: 1.9752e-05
#
# Epoch 56: LearningRateScheduler setting learning rate to 1.8541892953615504e-05.
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9410 - val_loss: 0.9790 - learning_rate: 1.8542e-05
#
# Epoch 57: LearningRateScheduler setting learning rate to 1.740602311353702e-05.
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9393 - val_loss: 0.9779 - learning_rate: 1.7406e-05
#
# Epoch 58: LearningRateScheduler setting learning rate to 1.6339736295707747e-05.
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9386 - val_loss: 0.9766 - learning_rate: 1.6340e-05
#
# Epoch 59: LearningRateScheduler setting learning rate to 1.53387704332925e-05.
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9374 - val_loss: 0.9758 - learning_rate: 1.5339e-05
#
# Epoch 60: LearningRateScheduler setting learning rate to 1.4399123008397966e-05.
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9366 - val_loss: 0.9748 - learning_rate: 1.4399e-05
#
# Epoch 61: LearningRateScheduler setting learning rate to 1.351703824538152e-05.
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9356 - val_loss: 0.9738 - learning_rate: 1.3517e-05
#
# Epoch 62: LearningRateScheduler setting learning rate to 1.2688990035262926e-05.
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9350 - val_loss: 0.9730 - learning_rate: 1.2689e-05
#
# Epoch 63: LearningRateScheduler setting learning rate to 1.19116674214743e-05.
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9327 - val_loss: 0.9722 - learning_rate: 1.1912e-05
#
# Epoch 64: LearningRateScheduler setting learning rate to 1.1181963500727731e-05.
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9329 - val_loss: 0.9714 - learning_rate: 1.1182e-05
#
# Epoch 65: LearningRateScheduler setting learning rate to 1.0496960908765236e-05.
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9318 - val_loss: 0.9709 - learning_rate: 1.0497e-05
#
# Epoch 66: LearningRateScheduler setting learning rate to 9.853921575005792e-06.
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9310 - val_loss: 0.9702 - learning_rate: 9.8539e-06
#
# Epoch 67: LearningRateScheduler setting learning rate to 9.25027391585413e-06.
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9301 - val_loss: 0.9695 - learning_rate: 9.2503e-06
#
# Epoch 68: LearningRateScheduler setting learning rate to 8.683606004465414e-06.
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9292 - val_loss: 0.9689 - learning_rate: 8.6836e-06
#
# Epoch 69: LearningRateScheduler setting learning rate to 8.15165191027462e-06.
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9294 - val_loss: 0.9684 - learning_rate: 8.1517e-06
#
# Epoch 70: LearningRateScheduler setting learning rate to 7.652284868761225e-06.
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9290 - val_loss: 0.9680 - learning_rate: 7.6523e-06
#
# Epoch 71: LearningRateScheduler setting learning rate to 7.1835087436550605e-06.
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9283 - val_loss: 0.9674 - learning_rate: 7.1835e-06
#
# Epoch 72: LearningRateScheduler setting learning rate to 6.743449916031881e-06.
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9277 - val_loss: 0.9668 - learning_rate: 6.7434e-06
#
# Epoch 73: LearningRateScheduler setting learning rate to 6.330348746519228e-06.
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9273 - val_loss: 0.9665 - learning_rate: 6.3303e-06
#
# Epoch 74: LearningRateScheduler setting learning rate to 5.942554025730227e-06.
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9265 - val_loss: 0.9661 - learning_rate: 5.9426e-06
#
# Epoch 75: LearningRateScheduler setting learning rate to 5.578515290248874e-06.
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9271 - val_loss: 0.9657 - learning_rate: 5.5785e-06
#
# Epoch 76: LearningRateScheduler setting learning rate to 5.236777699953539e-06.
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9263 - val_loss: 0.9653 - learning_rate: 5.2368e-06
#
# Epoch 77: LearningRateScheduler setting learning rate to 4.915974780891954e-06.
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9265 - val_loss: 0.9650 - learning_rate: 4.9160e-06
#
# Epoch 78: LearningRateScheduler setting learning rate to 4.6148241563841415e-06.
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9256 - val_loss: 0.9647 - learning_rate: 4.6148e-06
#
# Epoch 79: LearningRateScheduler setting learning rate to 4.332121997456218e-06.
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9259 - val_loss: 0.9644 - learning_rate: 4.3321e-06
#
# Epoch 80: LearningRateScheduler setting learning rate to 4.066737900163915e-06.
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9246 - val_loss: 0.9641 - learning_rate: 4.0667e-06
#
# Epoch 81: LearningRateScheduler setting learning rate to 3.817611043585211e-06.
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 8s/step - loss: 0.9246 - val_loss: 0.9638 - learning_rate: 3.8176e-06
#
# Epoch 82: LearningRateScheduler setting learning rate to 3.583745494033558e-06.
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9240 - val_loss: 0.9636 - learning_rate: 3.5837e-06
#
# Epoch 83: LearningRateScheduler setting learning rate to 3.3642065764953695e-06.
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9247 - val_loss: 0.9634 - learning_rate: 3.3642e-06
#
# Epoch 84: LearningRateScheduler setting learning rate to 3.1581166057329498e-06.
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9236 - val_loss: 0.9632 - learning_rate: 3.1581e-06
#
# Epoch 85: LearningRateScheduler setting learning rate to 2.964651684611692e-06.
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9234 - val_loss: 0.9630 - learning_rate: 2.9647e-06
#
# Epoch 86: LearningRateScheduler setting learning rate to 2.7830382889824196e-06.
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9239 - val_loss: 0.9627 - learning_rate: 2.7830e-06
#
# Epoch 87: LearningRateScheduler setting learning rate to 2.6125504928982947e-06.
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9232 - val_loss: 0.9626 - learning_rate: 2.6126e-06
#
# Epoch 88: LearningRateScheduler setting learning rate to 2.4525067669420108e-06.
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9230 - val_loss: 0.9624 - learning_rate: 2.4525e-06
#
# Epoch 89: LearningRateScheduler setting learning rate to 2.3022672034426998e-06.
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9227 - val_loss: 0.9622 - learning_rate: 2.3023e-06
#
# Epoch 90: LearningRateScheduler setting learning rate to 2.161231168582541e-06.
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9229 - val_loss: 0.9620 - learning_rate: 2.1612e-06
#
# Epoch 91: LearningRateScheduler setting learning rate to 2.028834954503375e-06.
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9236 - val_loss: 0.9619 - learning_rate: 2.0288e-06
#
# Epoch 92: LearningRateScheduler setting learning rate to 1.9045492179684596e-06.
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9228 - val_loss: 0.9618 - learning_rate: 1.9045e-06
#
# Epoch 93: LearningRateScheduler setting learning rate to 1.787877272803641e-06.
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9224 - val_loss: 0.9617 - learning_rate: 1.7879e-06
#
# Epoch 94: LearningRateScheduler setting learning rate to 1.6783526352815401e-06.
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9219 - val_loss: 0.9616 - learning_rate: 1.6784e-06
#
# Epoch 95: LearningRateScheduler setting learning rate to 1.5755374232851502e-06.
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9224 - val_loss: 0.9614 - learning_rate: 1.5755e-06
#
# Epoch 96: LearningRateScheduler setting learning rate to 1.4790206487490082e-06.
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9224 - val_loss: 0.9613 - learning_rate: 1.4790e-06
#
# Epoch 97: LearningRateScheduler setting learning rate to 1.3884164033779408e-06.
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9227 - val_loss: 0.9613 - learning_rate: 1.3884e-06
#
# Epoch 98: LearningRateScheduler setting learning rate to 1.3033625779779427e-06.
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - loss: 0.9217 - val_loss: 0.9612 - learning_rate: 1.3034e-06
#
# Epoch 99: LearningRateScheduler setting learning rate to 1.223519048174921e-06.
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9219 - val_loss: 0.9611 - learning_rate: 1.2235e-06
#
# Epoch 100: LearningRateScheduler setting learning rate to 1.1485667139128558e-06.
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 7s/step - loss: 0.9221 - val_loss: 0.9610 - learning_rate: 1.1486e-06

# %%
cnm3.initialize_online(T=T, model_LN=model_LN)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 400ms/step
#      1833384 [timeseries.py:      save():298] [1091161] No file saved

# %%
# if no GPU is available prediction is faster when the CNN is converted into a sparse matrix 
# if tf.test.is_gpu_available():
    # predict = model_LN.predict
    # dummy prediction to initialize CNN-ring model model_LN
    # predict(m[:1, ..., None])

dims = m[0].shape
kernel_size = model_LN.layers[1].weights[0].shape[0]
kernel_half = (kernel_size-1)//2
w_1 = model_LN.layers[1].weights[0].numpy().squeeze().transpose(2,0,1)
w_1 = w_1.reshape(len(w_1), -1)
w_2 = model_LN.layers[2].weights[0].numpy()
data = []
indices = []
indptr = [0]
for i in range(dims[0]):
    for j in range(dims[1]):
            tmp = np.zeros((dims[0]+kernel_size, dims[1]+kernel_size), dtype=np.float32)
            tmp[i:i+kernel_size, j:j+kernel_size] = w_2[i, j].dot(w_1).reshape(kernel_size, kernel_size)
            tmp = tmp[kernel_half:kernel_half+dims[0], kernel_half:kernel_half+dims[1]].ravel()
            ind = np.where(tmp!=0)[0]
            newdata = list(tmp[ind])
            data += newdata
            indices += list(ind)
            indptr += [len(newdata) + indptr[-1]]
w = csr_matrix((data, indices, indptr)).todia()

def predict(frame):
    return w.dot(frame.ravel()).reshape(dims)
# Out:
# /mnt/home/mpaez/miniconda3/envs/caiman_pytorch/lib/python3.11/site-packages/scipy/sparse/_base.py:1008: SparseEfficiencyWarning: Constructing a DIA matrix with 404 diagonals is inefficient
#   return self.tocoo(copy=copy).todia(copy=False)

# %%
cnm3.t_read = []
cnm3.t_bkgrd = []
cnm3.t_motion = []
cnm3.t_fit = []
for t in range(init_batch, T):
    # read frame
    t0 = time()
    frame = next(iterator)
    cnm3.t_read.append(time()-t0)
    # remove background
    t0 = time()
    frame = np.maximum(frame - np.squeeze(predict(
        frame.astype(np.float32)[None,...,None])), 0)
    cnm3.t_bkgrd.append(time()-t0)
    # motion correct
    t0 = time()
    frame = cnm3.mc_next(t, frame.astype(np.float32))
    cnm3.t_motion.append(time()-t0)
    # fit
    t0 = time()
    cnm3.fit_next(t, frame.ravel(order='F'))
    cnm3.t_fit.append(time()-t0)
    # add code to display whatever you want in order to guide the closed-loop experiment below

# %%
del iterator

# %%
# calculate time one would have to wait for next frame to arrive if reading directly from camera
t_all = np.cumsum(cnm3.t_read) + np.cumsum(cnm3.t_bkgrd) + np.cumsum(cnm3.t_motion) + np.cumsum(cnm3.t_fit)

t_wait=[1]
t_wait_total=0
for i in range(1, T-init_batch):
    t_wait.append(max(i/fr - t_all[i-1]-t_wait_total, 0))
    t_wait_total += t_wait[-1]
realtime = np.array(t_wait)>0
print('%g%s processed in real time. %g/%g frames' % 
      (100 * realtime.sum() / (T-init_batch), '%', realtime.sum(), T-init_batch))
# Out:
# 99.8644% processed in real time. 5892/5900 frames

# %%
plt.figure(figsize=(12,4))
for i, f in enumerate((lambda a: 1000*np.array(a), np.cumsum)):
    plt.subplot(1,2,1+i)
    plt.stackplot(np.arange(len(cnm3.t_fit)), f(cnm3.t_read), f(cnm3.t_bkgrd), f(cnm3.t_motion),
                  f(np.array(cnm3.t_fit) - np.array([cnm3.t_detect, cnm3.t_shapes, cnm3.t_stat]).sum(0)),
                  f(cnm3.t_detect), f(cnm3.t_shapes)+f(cnm3.t_stat))
    plt.gca().add_artist(plt.legend(labels=['read', 'background', 'motion', 'process', 'detect', 'shapes'], loc=2))
    plt.title('Processing time allocation')
    plt.xlabel('Frame #')
    plt.ylabel(('Processing time per frame [ms]', 'Cumulative processing time [s]')[i])
    if i==0:
        plt.fill_between(range(T-init_batch),[0]*(T-init_batch),
                 [plt.ylim()[1]]*(T-init_batch), where=realtime, 
                 color='y', alpha=.1, edgecolor='y', zorder=-11, label='real time')
        plt.gca().add_artist(plt.legend())
